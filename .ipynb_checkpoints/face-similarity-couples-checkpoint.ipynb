# %%
from matplotlib import pyplot as plt
from faces import *
from morphing import *
from metrics import *

# %% [markdown]
# ### Couples

# %%
ryan_sam, ryan_morphed, sam_morphed = get_average_face(ryan_resized, sam_resized)

fig, axes = plt.subplots(1, 3)
axes[0].imshow(ryan_morphed)
axes[0].set_title('Ryan Morphed'), axes[0].set_xticks([]), axes[0].set_yticks([])
axes[1].imshow(sam_morphed)
axes[1].set_title('Sam Morphed'), axes[1].set_xticks([]), axes[1].set_yticks([])
axes[2].imshow(ryan_sam)
axes[2].set_title('Average'), axes[2].set_xticks([]), axes[2].set_yticks([]);

# %%
print(get_face_similarity(ryan_resized, sam_resized, get_max_angle))
print(get_face_similarity(ryan_sam, sam_resized, get_max_angle))
print(get_face_similarity(ryan_resized, ryan_sam, get_max_angle))
# Out:
# 13.562020350981838
# 9.5729868004313
# 7.346677385866057

# %%
jared_rachelle, jared_morphed, rachelle_morphed = get_average_face(jared_resized, rachelle_resized)

fig, axes = plt.subplots(1, 3)
axes[0].imshow(jared_morphed)
axes[0].set_title('Jared Morphed'), axes[0].set_xticks([]), axes[0].set_yticks([])
axes[1].imshow(rachelle_morphed)
axes[1].set_title('Rachelle Morphed'), axes[1].set_xticks([]), axes[1].set_yticks([])
axes[2].imshow(jared_rachelle)
axes[2].set_title('Average'), axes[2].set_xticks([]), axes[2].set_yticks([]);

# %%
print(get_face_similarity(jared_resized, rachelle_resized, get_max_angle))
print(get_face_similarity(jared_rachelle, rachelle_resized, get_max_angle))
print(get_face_similarity(jared_resized, jared_rachelle, get_max_angle))
# Out:
# 13.533681903945654
# 7.018403175368093
# 7.3019816322493405

# %%
darren_amanda, darren_morphed, amanda_morphed = get_average_face(darren_resized, amanda_resized)

fig, axes = plt.subplots(1, 3)
axes[0].imshow(darren_morphed)
axes[0].set_title('Darren Morphed'), axes[0].set_xticks([]), axes[0].set_yticks([])
axes[1].imshow(amanda_morphed)
axes[1].set_title('Amanda Morphed'), axes[1].set_xticks([]), axes[1].set_yticks([])
axes[2].imshow(darren_amanda)
axes[2].set_title('Average'), axes[2].set_xticks([]), axes[2].set_yticks([]);

# %%
print(get_face_similarity(darren_resized, amanda_resized, get_max_angle))
print(get_face_similarity(darren_amanda, amanda_resized, get_max_angle))
print(get_face_similarity(darren_resized, darren_amanda, get_max_angle))
# Out:
# 9.582919323989644
# 6.151696638418136
# 7.704615980403981

# %%
roger_linda, roger_morphed, linda_morphed = get_average_face(roger_resized, linda_resized)

fig, axes = plt.subplots(1, 3)
axes[0].imshow(roger_morphed)
axes[0].set_title('Roger Morphed'), axes[0].set_xticks([]), axes[0].set_yticks([])
axes[1].imshow(linda_morphed)
axes[1].set_title('Linda Morphed'), axes[1].set_xticks([]), axes[1].set_yticks([])
axes[2].imshow(roger_linda)
axes[2].set_title('Average'), axes[2].set_xticks([]), axes[2].set_yticks([]);

# %%
print(get_face_similarity(roger_resized, linda_resized, get_max_angle))
print(get_face_similarity(roger_linda, linda_resized, get_max_angle))
print(get_face_similarity(roger_resized, roger_linda, get_max_angle))
# Out:
# 10.208904542174961
# 5.623274466898437
# 7.784199243922439
